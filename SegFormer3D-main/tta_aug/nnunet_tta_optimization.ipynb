# %%
# --- Standard Library ---
import os
import sys
import random
import time
import yaml

# --- Third-Party Libraries ---
import numpy as np
import torch
from tqdm import tqdm
from matplotlib import pyplot as plt
from termcolor import colored
from accelerate import Accelerator
from scipy.ndimage import (
    binary_closing,
    binary_opening,
    binary_dilation,
    binary_erosion,
    generate_binary_structure
)

# --- Local Imports ---
sys.path.append("..")
sys.path.append("SegFormer3D-main")

from dataloaders.build_dataset import build_dataset, build_dataloader
from architectures.build_architecture import build_architecture
from metrics.competition_metric import ULS23_evaluator

print(os.getcwd())
sys.path.append("../../../nnUNet")
# !pip install acvl_utils
# !pip install dynamic_network_architectures
# !pip install -e "C:\Users\Lazar\OneDrive\Desktop\RU Courses\AI in Medical Imaging\project\nnUNet"
from nnunetv2.inference.predict_from_raw_data import nnUNetPredictor

import nnunetv2


import os
import torch
from torch.utils.data import Dataset, DataLoader
import SimpleITK as sitk
import numpy as np
from glob import glob

from matplotlib import pyplot as plt
import matplotlib
matplotlib.use('TkAgg')
# Out:
# c:\Users\Lazar\OneDrive\Desktop\RU Courses\AI in Medical Imaging\project\aimi-project\SegFormer3D-main\tta_aug
# Requirement already satisfied: acvl_utils in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (0.2.5)
# Requirement already satisfied: numpy in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (1.26.4)
# Requirement already satisfied: batchgenerators in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (0.25.1)
# Requirement already satisfied: torch in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (2.5.1+cu118)
# Requirement already satisfied: SimpleITK in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (2.5.0)
# Requirement already satisfied: scikit-image in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (0.23.1)
# Requirement already satisfied: connected-components-3d in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (3.23.0)
# Requirement already satisfied: blosc2>=3.0.0b4 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl_utils) (3.3.4)
# Requirement already satisfied: ndindex in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (1.10.0)
# Requirement already satisfied: msgpack in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (1.1.0)
# Requirement already satisfied: platformdirs in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (4.3.8)
# Requirement already satisfied: numexpr in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (2.10.2)
# Requirement already satisfied: py-cpuinfo in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (9.0.0)
# Requirement already satisfied: requests in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b4->acvl_utils) (2.28.1)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (11.2.1)
# Requirement already satisfied: scipy in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (1.13.0)
# Requirement already satisfied: scikit-learn in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (1.2.2)
# Requirement already satisfied: future in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (1.0.0)
# Requirement already satisfied: pandas in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (2.2.3)
# Requirement already satisfied: unittest2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (1.1.0)
# Requirement already satisfied: threadpoolctl in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators->acvl_utils) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from pandas->batchgenerators->acvl_utils) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from pandas->batchgenerators->acvl_utils) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from pandas->batchgenerators->acvl_utils) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from python-dateutil>=2.8.2->pandas->batchgenerators->acvl_utils) (1.17.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->blosc2>=3.0.0b4->acvl_utils) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->blosc2>=3.0.0b4->acvl_utils) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->blosc2>=3.0.0b4->acvl_utils) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->blosc2>=3.0.0b4->acvl_utils) (2025.4.26)
# Requirement already satisfied: networkx>=2.8 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image->acvl_utils) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image->acvl_utils) (2.33.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image->acvl_utils) (2025.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image->acvl_utils) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image->acvl_utils) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-learn->batchgenerators->acvl_utils) (1.5.1)
# Requirement already satisfied: filelock in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch->acvl_utils) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch->acvl_utils) (4.13.2)
# Requirement already satisfied: jinja2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch->acvl_utils) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch->acvl_utils) (2023.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch->acvl_utils) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from sympy==1.13.1->torch->acvl_utils) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from jinja2->torch->acvl_utils) (3.0.2)
# Collecting argparse (from unittest2->batchgenerators->acvl_utils)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from unittest2->batchgenerators->acvl_utils) (1.4.0)
# Requirement already satisfied: linecache2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from traceback2->unittest2->batchgenerators->acvl_utils) (1.0.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: dynamic_network_architectures in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (0.3.1)
# Requirement already satisfied: torch>=1.6.0a in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from dynamic_network_architectures) (2.5.1+cu118)
# Requirement already satisfied: numpy in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from dynamic_network_architectures) (1.26.4)
# Requirement already satisfied: filelock in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (4.13.2)
# Requirement already satisfied: networkx in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (2023.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=1.6.0a->dynamic_network_architectures) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from sympy==1.13.1->torch>=1.6.0a->dynamic_network_architectures) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from jinja2->torch>=1.6.0a->dynamic_network_architectures) (3.0.2)
# Obtaining file:///C:/Users/Lazar/OneDrive/Desktop/RU%20Courses/AI%20in%20Medical%20Imaging/project/nnUNet
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: torch>=2.1.2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2.5.1+cu118)
# Requirement already satisfied: acvl-utils<0.3,>=0.2.3 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.2.5)
# Requirement already satisfied: dynamic-network-architectures<0.4,>=0.3.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.3.1)
# Requirement already satisfied: tqdm in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (4.65.0)
# Requirement already satisfied: scipy in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (1.13.0)
# Requirement already satisfied: batchgenerators>=0.25.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.25.1)
# Requirement already satisfied: numpy>=1.24 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (1.2.2)
# Requirement already satisfied: scikit-image>=0.19.3 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.23.1)
# Requirement already satisfied: SimpleITK>=2.2.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2.5.0)
# Requirement already satisfied: pandas in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2.2.3)
# Requirement already satisfied: graphviz in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.20.3)
# Requirement already satisfied: tifffile in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2025.5.10)
# Requirement already satisfied: requests in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2.28.1)
# Requirement already satisfied: nibabel in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (5.1.0)
# Requirement already satisfied: matplotlib in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (3.7.1)
# Requirement already satisfied: seaborn in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.13.2)
# Requirement already satisfied: imagecodecs in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (2025.3.30)
# Requirement already satisfied: yacs in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.1.8)
# Requirement already satisfied: batchgeneratorsv2>=0.2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.2.3)
# Requirement already satisfied: einops in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (0.7.0)
# Requirement already satisfied: blosc2>=3.0.0b1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from nnunetv2==2.6.1) (3.3.4)
# Requirement already satisfied: connected-components-3d in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from acvl-utils<0.3,>=0.2.3->nnunetv2==2.6.1) (3.23.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators>=0.25.1->nnunetv2==2.6.1) (11.2.1)
# Requirement already satisfied: future in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators>=0.25.1->nnunetv2==2.6.1) (1.0.0)
# Requirement already satisfied: unittest2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators>=0.25.1->nnunetv2==2.6.1) (1.1.0)
# Requirement already satisfied: threadpoolctl in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgenerators>=0.25.1->nnunetv2==2.6.1) (3.6.0)
# Requirement already satisfied: fft-conv-pytorch in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from batchgeneratorsv2>=0.2->nnunetv2==2.6.1) (1.2.0)
# Requirement already satisfied: ndindex in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b1->nnunetv2==2.6.1) (1.10.0)
# Requirement already satisfied: msgpack in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b1->nnunetv2==2.6.1) (1.1.0)
# Requirement already satisfied: platformdirs in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b1->nnunetv2==2.6.1) (4.3.8)
# Requirement already satisfied: numexpr in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b1->nnunetv2==2.6.1) (2.10.2)
# Requirement already satisfied: py-cpuinfo in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from blosc2>=3.0.0b1->nnunetv2==2.6.1) (9.0.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image>=0.19.3->nnunetv2==2.6.1) (3.4.2)
# Requirement already satisfied: imageio>=2.33 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image>=0.19.3->nnunetv2==2.6.1) (2.33.0)
# Requirement already satisfied: packaging>=21 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image>=0.19.3->nnunetv2==2.6.1) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-image>=0.19.3->nnunetv2==2.6.1) (0.4)
# Requirement already satisfied: filelock in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=2.1.2->nnunetv2==2.6.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=2.1.2->nnunetv2==2.6.1) (4.13.2)
# Requirement already satisfied: jinja2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=2.1.2->nnunetv2==2.6.1) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=2.1.2->nnunetv2==2.6.1) (2023.6.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from torch>=2.1.2->nnunetv2==2.6.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from sympy==1.13.1->torch>=2.1.2->nnunetv2==2.6.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from jinja2->torch>=2.1.2->nnunetv2==2.6.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from matplotlib->nnunetv2==2.6.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from python-dateutil>=2.7->matplotlib->nnunetv2==2.6.1) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from pandas->nnunetv2==2.6.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from pandas->nnunetv2==2.6.1) (2025.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->nnunetv2==2.6.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->nnunetv2==2.6.1) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->nnunetv2==2.6.1) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from requests->nnunetv2==2.6.1) (2025.4.26)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from scikit-learn->nnunetv2==2.6.1) (1.5.1)
# Requirement already satisfied: colorama in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from tqdm->nnunetv2==2.6.1) (0.4.6)
# Collecting argparse (from unittest2->batchgenerators>=0.25.1->nnunetv2==2.6.1)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from unittest2->batchgenerators>=0.25.1->nnunetv2==2.6.1) (1.4.0)
# Requirement already satisfied: linecache2 in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from traceback2->unittest2->batchgenerators>=0.25.1->nnunetv2==2.6.1) (1.0.0)
# Requirement already satisfied: PyYAML in c:\users\lazar\anaconda3\envs\aimi\lib\site-packages (from yacs->nnunetv2==2.6.1) (6.0.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Building wheels for collected packages: nnunetv2
#   Building editable for nnunetv2 (pyproject.toml): started
#   Building editable for nnunetv2 (pyproject.toml): finished with status 'done'
#   Created wheel for nnunetv2: filename=nnunetv2-2.6.1-0.editable-py3-none-any.whl size=16851 sha256=178aae6b8a9418ab800eb40b40da381ff931997b06f631937cd7c32738cb75e3
#   Stored in directory: C:\Users\Lazar\AppData\Local\Temp\pip-ephem-wheel-cache-ec9r1dv4\wheels\f9\6c\08\ebaa9af0608797712da0f0af034741ffd0c1661d0c73192d22
# Successfully built nnunetv2
# Installing collected packages: argparse, nnunetv2
#
#   Attempting uninstall: nnunetv2
#
#     Found existing installation: nnunetv2 2.6.1
#
#     Uninstalling nnunetv2-2.6.1:
#
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#    -------------------- ------------------- 1/2 [nnunetv2]
#       Successfully uninstalled nnunetv2-2.6.1
#    -------------------- ------------------- 1/2 [nnunetv2]
#    ---------------------------------------- 2/2 [nnunetv2]
#
# Successfully installed argparse-1.4.0 nnunetv2-2.6.1

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
def test_time_dilation(input_tensor):
    # Convert to NumPy and squeeze batch and channel dimensions
    volume = input_tensor.squeeze().cpu().numpy()
    
    # Apply binary dilation
    dilated = binary_dilation(volume, structure=np.ones((3, 3, 3)))

    return dilated.astype(np.uint8)

def test_time_2xdilation(input_tensor):
    volume = input_tensor.squeeze().cpu().numpy()
    
    # Apply binary dilation twice
    dilated = binary_dilation(volume, structure=np.ones((3, 3, 3)))
    dilated = binary_dilation(dilated, structure=np.ones((3, 3, 3)))

    return dilated.astype(np.uint8)

def test_time_opening(input_tensor):
    volume = input_tensor.squeeze().cpu().numpy()
    
    # Apply binary opening: erosion followed by dilation
    opened = binary_erosion(volume, structure=np.ones((3, 3, 3)))
    opened = binary_dilation(opened, structure=np.ones((3, 3, 3)))

    return opened.astype(np.uint8)

def test_time_closing(input_tensor):
    volume = input_tensor.squeeze().cpu().numpy()
    
    # Apply binary closing: dilation followed by erosion
    closed = binary_dilation(volume, structure=np.ones((3, 3, 3)))
    closed = binary_erosion(closed, structure=np.ones((3, 3, 3)))

    return closed.astype(np.uint8)

def test_time_shift(model, input_tensor, threshold=0.5):
    predictions = []

    device = model.device.type
    input_tensor = input_tensor.to(device)

    shifts = [
        (0, 0, 0),
        (5, 0, 0), 
        # (-5, 0, 0),
        # (0, 5, 0), 
        (0, -5, 0),
        # (0, 0, 5), 
        (0, 0, -5),
    ]

    with torch.no_grad():
        for dz, dx, dy in shifts:
            augmented = input_tensor.clone()

            # Shift
            augmented = torch.roll(augmented, shifts=(dz, dx, dy), dims=(1, 2, 3))

            # Model inference
            logits = model.predict_logits_from_preprocessed_data(input_tensor).unsqueeze(0)[:, 1:, ...]
            predicted = torch.sigmoid(logits)
            pred = predicted > threshold

            # Undo shift
            pred = torch.roll(pred, shifts=(-dz, -dx, -dy), dims=(1, 2, 3))
            predictions.append(pred.float())

    avg_prediction = torch.stack(predictions).mean(dim=0, keepdims=True)

    # --- Morphological smoothing ---
    # Convert to NumPy for processing
    pred_np = avg_prediction.squeeze().cpu().numpy()

    # Binarize
    binary_pred = pred_np > threshold
    return binary_pred

# %%
class NiiSliceDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transform=None):
        self.images_dir = images_dir
        self.labels_dir = labels_dir
        self.transform = transform

        # List all image slices
        self.image_paths = sorted(glob(os.path.join(images_dir, "MIX_*_*.nii.gz")))
        
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        image_path = self.image_paths[idx]

        # Extract ID, e.g., MIX_00001_0000.nii.gz -> MIX_00001
        basename = os.path.basename(image_path)
        id_part = "_".join(basename.split("_")[:2])  # MIX_00001

        label_path = os.path.join(self.labels_dir, f"{id_part}.nii.gz")

        # Read image slice (single slice)
        image_itk = sitk.ReadImage(image_path)
        image = sitk.GetArrayFromImage(image_itk).astype(np.float32)

        # Read full label volume
        label_itk = sitk.ReadImage(label_path)
        label = sitk.GetArrayFromImage(label_itk).astype(np.int64)

        if self.transform:
            image, label = self.transform(image, label)

        # Convert to torch tensors
        image_tensor = torch.from_numpy(image) 
        label_tensor = torch.from_numpy(label) 

        return image_tensor, label_tensor

# %%
evaluator = ULS23_evaluator()

##################################################################################################
def seed_everything(seed) -> None:
    # seed = config["training_parameters"]["seed"]
    os.environ["PYTHONHASHSEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def _run_eval(model, val_dataloader) -> None:
    """_summary_"""
    # Tell wandb to watch the model and optimizer values

    print("[info] -- Starting model evaluation")

    # Initialize the training loss for the current Epoch
    original_dice_total = 0.0
    original_uls_metric_total = 0.0
    dilated_uls_metric_total = 0.0
    dilatedx2_uls_metric_total = 0.0
    opening_uls_metric_total = 0.0
    closing_uls_metric_total = 0.0
    shift_uls_metric_total = 0.0


    ULS_per_threshold = [0.0]*9
    thresholds = np.linspace(0.1, 0.9, 9)
    

    # DATA IS 1x1x64x128x128, NO SPACINGS USED
    with torch.no_grad():
        for index, (data, labels) in enumerate(tqdm(val_dataloader)):

            logits = model.predict_logits_from_preprocessed_data(data).unsqueeze(0)[:, 1:, ...]
            predicted = torch.sigmoid(logits)

            for i, threshold in enumerate(thresholds):
                y_pred = predicted > threshold
                y_true = labels.unsqueeze(0)

                # SANITY CHECK
                # plt.imshow(y_pred[0, 0, 32])
                # plt.show()

                ULS_per_threshold[i] += evaluator.ULS_score_metric(y_pred, y_true)

    ULS_per_threshold = np.array(ULS_per_threshold)/float(index + 1)
    best_index = np.argmax(ULS_per_threshold)
    best_threshold = thresholds[best_index]

    print(ULS_per_threshold, best_threshold)


    # set epoch to shift data order each epoch
    # self.val_dataloader.sampler.set_epoch(self.current_epoch)
    with torch.no_grad():
        for index, (data, labels) in enumerate(tqdm(val_dataloader)):

            logits = model.predict_logits_from_preprocessed_data(data).unsqueeze(0)[:, 1:, ...]
            predicted = torch.sigmoid(logits)
            y_pred = predicted > best_threshold
            y_true = labels.unsqueeze(0)

            original_uls_metric_total += evaluator.ULS_score_metric(y_pred, y_true)
            # print(f"Orgi ULS: {original_uls_metric}")

            # Test-time dilation
            dilated_pred = test_time_dilation(y_pred.float())
            dilated_uls_metric_total += evaluator.ULS_score_metric(
                torch.tensor(dilated_pred).unsqueeze(0).unsqueeze(0).to(y_true.device),
                y_true,
            )

            # Test-time 2x dilation
            dilatedx2_pred = test_time_2xdilation(y_pred.float())
            dilatedx2_uls_metric_total += evaluator.ULS_score_metric(
                torch.tensor(dilatedx2_pred).unsqueeze(0).unsqueeze(0).to(y_true.device),
                y_true,
            )

            # Test-time opening
            opened_pred = test_time_opening(y_pred.float())
            opening_uls_metric_total += evaluator.ULS_score_metric(
                torch.tensor(opened_pred).unsqueeze(0).unsqueeze(0).to(y_true.device),
                y_true,
            )

            # Test-time closing
            closed_pred = test_time_closing(y_pred.float())
            closing_uls_metric_total += evaluator.ULS_score_metric(
                torch.tensor(closed_pred).unsqueeze(0).unsqueeze(0).to(y_true.device),
                y_true,
            )

            # Test-time shift
            shifted_pred = test_time_shift(model, data, threshold=best_threshold)
            shift_uls_metric_total += evaluator.ULS_score_metric(
                torch.tensor(shifted_pred).unsqueeze(0).unsqueeze(0).to(y_true.device),
                y_true,
            )

    # Average across batches
    divisor = float(index + 1)
    original_uls_metric_total /= divisor
    dilated_uls_metric_total /= divisor
    dilatedx2_uls_metric_total /= divisor
    opening_uls_metric_total /= divisor
    closing_uls_metric_total /= divisor
    shift_uls_metric_total /= divisor


    # Print metrics
    print(
        f"Original ULS: {colored(f'{original_uls_metric_total:.5f}', 'green')} | "
        f"Dilated: {colored(f'{dilated_uls_metric_total:.5f}', 'cyan')} | "
        f"2x Dilated: {colored(f'{dilatedx2_uls_metric_total:.5f}', 'cyan')} | "
        f"Opening: {colored(f'{opening_uls_metric_total:.5f}', 'cyan')} | "
        f"Closing: {colored(f'{closing_uls_metric_total:.5f}', 'cyan')} | "
        f"Shifted: {colored(f'{shift_uls_metric_total:.5f}', 'cyan')}"
    )

    return ULS_per_threshold

# %%
predictor.device.type
# Out:
# 'cuda'

# %%
# set seed
seed_everything(42)


def load_model():
    start_model_load_time = time.time()
    
    # Set up the nnUNetPredictor
    predictor = nnUNetPredictor(
        tile_step_size=0.5,
        use_gaussian=True,
        use_mirroring=False, # False is faster but less accurate
        device=torch.device(type='cuda', index=0),
        verbose=False,
        verbose_preprocessing=False,
        allow_tqdm=False
    )
    # Initialize the network architecture, loads the checkpoint
    predictor.initialize_from_trained_model_folder(
        fr"C:\Users\Lazar\OneDrive\Desktop\RU Courses\AI in Medical Imaging\project\aimi-project\SegFormer3D-main\data\local_data\nnUNetTrainer_ULS_400_QuarterLR__nnUNetResEncUNetMPlans__3d_fullres", # Path always relative to /opt/ml/model/
        use_folds=[0],
        checkpoint_name="checkpoint_best.pth", # TODO: export the best checkpoint from the training job and change this to checkpoint_best.pth
    )
    end_model_load_time = time.time()
    print(f"Model loading runtime: {end_model_load_time - start_model_load_time}s")
    return predictor


predictor = load_model()


images_dir = r"C:\Users\Lazar\OneDrive\Desktop\RU Courses\AI in Medical Imaging\project\aimi-project\SegFormer3D-main\data\local_data\nnunet_data\imagesVal"
labels_dir = r"C:\Users\Lazar\OneDrive\Desktop\RU Courses\AI in Medical Imaging\project\aimi-project\SegFormer3D-main\data\local_data\nnunet_data\labelsVal"

dataset = NiiSliceDataset(images_dir, labels_dir)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

print("[info] -- Running evaluation only.")
ULS_per_threshold = _run_eval(predictor, dataloader)
# Out:
# Model loading runtime: 3.185537099838257s
# [info] -- Running evaluation only.
# [info] -- Starting model evaluation
# 100%|██████████| 1155/1155 [55:00<00:00,  2.86s/it]
# [0.54725477 0.55873257 0.56346872 0.56544667 0.56639801 0.56686143
#  0.56664409 0.56499098 0.55830482] 0.6
# 100%|██████████| 1155/1155 [1:27:55<00:00,  4.57s/it]
# Original ULS: 0.56686 | Dilated: 0.44240 | 2x Dilated: 0.33654 | Opening: 0.51330 | Closing: 0.56719 | Shifted: 0.39253

# %%
print(ULS_per_threshold)
# Out:
# [0.54725477 0.55873257 0.56346872 0.56544667 0.56639801 0.56686143
#  0.56664409 0.56499098 0.55830482]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Example data (replace with your actual data)
thresholds = np.linspace(0.1, 0.9, 9)

# Set seaborn style
sns.set_theme(style="whitegrid", context="talk")


# #0D92F4, #C62E2E

# Create the plot
plt.figure(figsize=(8, 5))
sns.lineplot(x=thresholds, y=[0.55682154, 0.55853287, 0.5591937,  0.55975669, 0.56031297, 0.56064882, 0.56097877, 0.5611234, 0.56077012], 
             marker="o", linewidth=2.5, color="#F95454", label="SegFormer3D")
sns.lineplot(x=thresholds, y=ULS_per_threshold, marker="o", linewidth=2.5, color="#77CDFF", label="nnUNetv2")

# Labels and title
plt.xlabel("Threshold", fontsize=14)
plt.ylabel("ULS Score", fontsize=14)
plt.title("ULS Score vs. Threshold", fontsize=16)
plt.xticks(thresholds, rotation=45)
# plt.ylim(0, 1)
plt.grid(True)
plt.legend()

# Show the plot
plt.tight_layout()
plt.savefig("./threshold_optimization.pdf")
